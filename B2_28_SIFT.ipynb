# %%
pip install opencv-contrib-python

# %%
import cv2
import matplotlib.pyplot as plt

# Load the two images
img1 = cv2.imread('box.png', cv2.IMREAD_GRAYSCALE)         # Query Image
img2 = cv2.imread('box_in_scene.png', cv2.IMREAD_GRAYSCALE)  # Train Image

# Initialize SIFT detector
sift = cv2.SIFT_create()

# Find keypoints and descriptors
kp1, des1 = sift.detectAndCompute(img1, None)
kp2, des2 = sift.detectAndCompute(img2, None)

# Use BFMatcher to find matches between descriptors
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

# Match descriptors
matches = bf.match(des1, des2)

# Sort matches by distance (best matches first)
matches = sorted(matches, key=lambda x: x.distance)

# Draw top 20 matches
matched_img = cv2.drawMatches(img1, kp1, img2, kp2, matches[:20], None, flags=2)

# Display using matplotlib
plt.figure(figsize=(15, 8))
plt.imshow(matched_img)
plt.title("SIFT Keypoint Matches")
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the two images
img1 = cv2.imread('graf1.png', cv2.IMREAD_GRAYSCALE)         # Query Image
img2 = cv2.imread('graf3.png', cv2.IMREAD_GRAYSCALE)  # Train Image

# Initialize SIFT detector
sift = cv2.SIFT_create()

# Find keypoints and descriptors
kp1, des1 = sift.detectAndCompute(img1, None)
kp2, des2 = sift.detectAndCompute(img2, None)

# Use BFMatcher to find matches between descriptors
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

# Match descriptors
matches = bf.match(des1, des2)

# Sort matches by distance (best matches first)
matches = sorted(matches, key=lambda x: x.distance)

# Draw top 20 matches
matched_img = cv2.drawMatches(img1, kp1, img2, kp2, matches[:20], None, flags=2)

# Display using matplotlib
plt.figure(figsize=(15, 8))
plt.imshow(matched_img)
plt.title("SIFT Keypoint Matches")
plt.axis('off')
plt.show()
